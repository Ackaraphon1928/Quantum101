# %%
import qiskit

print(qiskit.__version__)
# Out:
# 2.5.0

# %%
import sys
print(sys.executable)
# Out:
# d:\CEDT\CEDTY3S1\QTCOMP_std\quantum1\Scripts\python.exe

# %%
import pylatexenc
print(pylatexenc.__version__)
# Out:
# 2.10

# %% [markdown]
# ## Create Quantum Circuit

# %%
from qiskit import QuantumCircuit
import pylatexenc as pl

qc = QuantumCircuit(1)

qc.draw("mpl")

# %%
qc.h(0)

qc.draw("mpl")

# %%
print(qc.)
# Out:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %%
qc2 = QuantumCircuit(1,1)

qc2.h(0)

qc2.measure(0,0)

qc2.draw("mpl")

# %%
from qiskit_aer import AerSimulator

sim = AerSimulator()

job = sim.run(qc2, shots=1000)

result = job.result()

counts = result.get_counts()

print(counts)
# Out:
# {'1': 486, '0': 514}

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts)

# %%
qc3 = QuantumCircuit(1,1)
qc3.measure(0,0)
qc3.draw("mpl")

# %%
print(qc3.qubits)
# Out:
# [<Qubit register=(1, "q"), index=0>]

# %%
from qiskit_aer import AerSimulator

sim = AerSimulator()

job = sim.run(qc3, shots=1000)

result = job.result()

counts = result.get_counts()

print(counts)
# Out:
# {'0': 1000}
